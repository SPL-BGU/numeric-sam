# %% [markdown]
# # Creating Trajectories Demo Notebook

# %%
from pathlib import Path

# %% [markdown]
# To create trajectories the code below can be used. Trajectories are composed from PDDL domain file, a problem file and a solution file. The solution file is a *".solution"* file containing the actions that were executed to solve the problem. The solution file can be generated using the planner of your choice. The code below uses presents an example of how a plan file should look like given that the planner that created it is ENHSP.
#
# ```
# (get_log)
# (get_log)
# (get_log)
# (craft_plank)
# (craft_plank)
# (craft_plank)
# (craft_stick)
# (craft_stick)
# (craft_tree_tap)
# (place_tree_tap)
# (craft_wooden_pogo)
# ```
#
# Note - the trajectory creator iterates over the solution files and expects the problem file to be with the same name. For example, if the solution file is named *pfile1.solution*, the code expects the problem file to be named *pfile1.pddl*. If the problem file is named differently, the code will not be able to find it and will throw an error.
#
# After the trajectory is created, it will be saved in the input directory under the same name with the file extension *".trajectory"*.

# %%
from observations.experiments_trajectories_creator import ExperimentTrajectoriesCreator, SolverType

EXAMPLES_PATH = Path("demos_data")

trajectory_creator = ExperimentTrajectoriesCreator(domain_file_name="depot_numeric.pddl", working_directory_path=EXAMPLES_PATH)
selected_solver = SolverType.enhsp
trajectory_creator.fix_solution_files(selected_solver)
trajectory_creator.create_domain_trajectories()

# %%
DEPOTS_TRAJECTORY_PATH = EXAMPLES_PATH / "pfile0.trajectory"

with open(DEPOTS_TRAJECTORY_PATH, "rt") as trajectory_file:
    for line in trajectory_file.readlines():
        print(line)
# Out:
# ((:init (= (current_load truck0) 0.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 0.0) (at pallet2 depot2) (at crate5 distributor1) (at crate8 depot3) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at truck0 distributor2) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 depot0) (at crate3 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at crate0 distributor1) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet2) (clear crate8) (clear crate7) (clear pallet1) (clear pallet0) (clear crate5) (clear crate4) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate8 crate3) (on crate4 pallet4) (on crate7 crate6) (on crate2 crate1) (on crate5 crate0) (on crate6 crate2) (on crate1 pallet6) (on crate0 pallet5) (on crate3 pallet3))
#
# (operator: (drive truck0 distributor2 depot3))
#
# (:state (= (current_load truck0) 0.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 10.0) (at pallet2 depot2) (at crate8 depot3) (at crate5 distributor1) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at truck0 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at crate0 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate6 distributor2) (at truck1 depot0) (at crate7 distributor2) (at pallet6 distributor2) (at crate3 depot3) (clear crate8) (clear pallet2) (clear crate7) (clear pallet1) (clear pallet0) (clear crate5) (clear crate4) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate8 crate3) (on crate7 crate6) (on crate4 pallet4) (on crate2 crate1) (on crate5 crate0) (on crate6 crate2) (on crate1 pallet6) (on crate0 pallet5) (on crate3 pallet3))
#
# (operator: (drive truck1 depot0 distributor2))
#
# (:state (= (current_load truck0) 0.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 20.0) (at pallet2 depot2) (at crate8 depot3) (at crate5 distributor1) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at truck0 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at crate0 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate6 distributor2) (at crate7 distributor2) (at truck1 distributor2) (at pallet6 distributor2) (at crate3 depot3) (clear pallet2) (clear crate8) (clear crate7) (clear pallet1) (clear pallet0) (clear crate5) (clear crate4) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate8 crate3) (on crate7 crate6) (on crate4 pallet4) (on crate5 crate0) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6) (on crate0 pallet5) (on crate3 pallet3))
#
# (operator: (lift hoist3 crate8 crate3 depot3))
#
# (:state (= (current_load truck0) 0.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 21.0) (at pallet2 depot2) (at crate5 distributor1) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate3 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at truck0 depot3) (at hoist2 depot2) (at crate0 distributor1) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear crate3) (clear pallet0) (clear pallet1) (clear crate4) (clear pallet2) (clear crate5) (clear crate7) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (on crate7 crate6) (on crate4 pallet4) (on crate5 crate0) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6) (on crate0 pallet5) (on crate3 pallet3) (lifting hoist3 crate8))
#
# (operator: (load hoist3 crate8 truck0 depot3))
#
# (:state (= (current_load truck0) 67.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 21.0) (at pallet2 depot2) (at crate5 distributor1) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate3 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at truck0 depot3) (at hoist2 depot2) (at crate0 distributor1) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear crate3) (clear pallet2) (clear crate7) (clear pallet1) (clear pallet0) (clear crate5) (clear crate4) (available hoist5) (available hoist6) (available hoist4) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate2 crate1) (on crate5 crate0) (on crate6 crate2) (on crate1 pallet6) (on crate0 pallet5) (on crate3 pallet3)  (in crate8 truck0))
#
# (operator: (lift hoist3 crate3 pallet3 depot3))
#
# (:state (= (current_load truck0) 67.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 22.0) (at pallet2 depot2) (at crate5 distributor1) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at truck0 depot3) (at hoist2 depot2) (at crate0 distributor1) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet3) (clear pallet0) (clear pallet1) (clear crate4) (clear pallet2) (clear crate5) (clear crate7) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (on crate7 crate6) (on crate4 pallet4) (on crate5 crate0) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6) (on crate0 pallet5) (lifting hoist3 crate3) (in crate8 truck0))
#
# (operator: (load hoist3 crate3 truck0 depot3))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 22.0) (at pallet2 depot2) (at crate5 distributor1) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at truck0 depot3) (at hoist2 depot2) (at crate0 distributor1) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet2) (clear crate7) (clear pallet1) (clear pallet0) (clear crate5) (clear crate4) (clear pallet3) (available hoist5) (available hoist6) (available hoist4) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate2 crate1) (on crate5 crate0) (on crate6 crate2) (on crate1 pallet6) (on crate0 pallet5)  (in crate8 truck0) (in crate3 truck0))
#
# (operator: (lift hoist5 crate5 crate0 distributor1))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 23.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at truck0 depot3) (at hoist2 depot2) (at crate0 distributor1) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet3) (clear pallet0) (clear pallet1) (clear crate4) (clear pallet2) (clear crate0) (clear crate7) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6) (on crate0 pallet5) (lifting hoist5 crate5) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (drive truck0 depot3 distributor1))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 33.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at truck0 distributor1) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at crate0 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet2) (clear crate7) (clear pallet1) (clear pallet0) (clear crate4) (clear crate0) (clear pallet3) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6) (on crate0 pallet5) (lifting hoist5 crate5) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (load hoist5 crate5 truck0 distributor1))
#
# (:state (= (current_load truck0) 192.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 33.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at truck0 distributor1) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at crate0 distributor1) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet2) (clear crate7) (clear pallet1) (clear pallet0) (clear crate4) (clear crate0) (clear pallet3) (available hoist5) (available hoist6) (available hoist4) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6) (on crate0 pallet5)  (in crate8 truck0) (in crate3 truck0) (in crate5 truck0))
#
# (operator: (lift hoist5 crate0 pallet5 distributor1))
#
# (:state (= (current_load truck0) 192.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 34.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at truck0 distributor1) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet3) (clear pallet0) (clear pallet1) (clear crate4) (clear pallet2) (clear pallet5) (clear crate7) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6) (lifting hoist5 crate0) (in crate8 truck0) (in crate3 truck0) (in crate5 truck0))
#
# (operator: (load hoist5 crate0 truck0 distributor1))
#
# (:state (= (current_load truck0) 280.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 34.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at truck0 distributor1) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet2) (clear crate7) (clear pallet5) (clear pallet1) (clear pallet0) (clear crate4) (clear pallet3) (available hoist5) (available hoist6) (available hoist4) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6)  (in crate0 truck0) (in crate8 truck0) (in crate3 truck0) (in crate5 truck0))
#
# (operator: (drive truck0 distributor1 depot3))
#
# (:state (= (current_load truck0) 280.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 44.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at truck0 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet2) (clear crate7) (clear pallet5) (clear pallet1) (clear pallet0) (clear crate4) (clear pallet3) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6)  (in crate0 truck0) (in crate8 truck0) (in crate3 truck0) (in crate5 truck0))
#
# (operator: (unload hoist3 crate5 truck0 depot3))
#
# (:state (= (current_load truck0) 195.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 44.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at truck0 depot3) (at hoist2 depot2) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet2) (clear crate7) (clear pallet5) (clear pallet1) (clear pallet0) (clear crate4) (clear pallet3) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (on crate7 crate6) (on crate4 pallet4) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6) (lifting hoist3 crate5) (in crate0 truck0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (drop hoist3 crate5 pallet3 depot3))
#
# (:state (= (current_load truck0) 195.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 44.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at truck0 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate7 distributor2) (at crate5 depot3) (at pallet6 distributor2) (clear crate5) (clear pallet0) (clear pallet1) (clear crate4) (clear pallet2) (clear pallet5) (clear crate7) (available hoist5) (available hoist6) (available hoist4) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate6 crate2) (on crate1 pallet6) (on crate7 crate6) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1)  (in crate0 truck0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (drive truck0 depot3 distributor2))
#
# (:state (= (current_load truck0) 195.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 54.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at truck0 distributor2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate7 distributor2) (at crate5 depot3) (at pallet6 distributor2) (clear pallet2) (clear crate7) (clear pallet5) (clear pallet1) (clear crate5) (clear pallet0) (clear crate4) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6)  (in crate0 truck0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (unload hoist6 crate0 truck0 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 54.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate5 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet2) (clear crate7) (clear pallet5) (clear pallet1) (clear pallet0) (clear crate5) (clear crate4) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6) (lifting hoist6 crate0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (load hoist6 crate0 truck1 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 88.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 54.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate5 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate1 distributor2) (at crate7 distributor2) (at pallet6 distributor2) (clear pallet2) (clear crate7) (clear pallet5) (clear pallet1) (clear crate5) (clear pallet0) (clear crate4) (available hoist5) (available hoist4) (available hoist6) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate7 crate6) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6)  (in crate8 truck0) (in crate3 truck0) (in crate0 truck1))
#
# (operator: (lift hoist6 crate7 crate6 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 88.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 55.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate5 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate1 distributor2) (at pallet6 distributor2) (clear crate5) (clear pallet0) (clear crate4) (clear pallet2) (clear crate6) (clear pallet5) (clear pallet1) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6) (lifting hoist6 crate7) (in crate8 truck0) (in crate3 truck0) (in crate0 truck1))
#
# (operator: (load hoist6 crate7 truck1 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 146.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 55.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate5 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate1 distributor2) (at pallet6 distributor2) (clear pallet2) (clear crate6) (clear pallet5) (clear pallet1) (clear crate5) (clear pallet0) (clear crate4) (available hoist5) (available hoist4) (available hoist6) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6)  (in crate7 truck1) (in crate8 truck0) (in crate3 truck0) (in crate0 truck1))
#
# (operator: (drive truck0 distributor2 distributor1))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 146.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 65.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at truck0 distributor1) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate6 distributor2) (at truck1 distributor2) (at crate5 depot3) (at pallet6 distributor2) (clear pallet2) (clear crate6) (clear pallet5) (clear pallet1) (clear pallet0) (clear crate5) (clear crate4) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6)  (in crate7 truck1) (in crate8 truck0) (in crate3 truck0) (in crate0 truck1))
#
# (operator: (drive truck1 distributor2 depot0))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 146.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 75.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at truck0 distributor1) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate6 distributor2) (at crate5 depot3) (at pallet6 distributor2) (at truck1 depot0) (clear pallet2) (clear crate6) (clear pallet5) (clear pallet1) (clear crate5) (clear pallet0) (clear crate4) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate6 crate2) (on crate1 pallet6)  (in crate7 truck1) (in crate8 truck0) (in crate3 truck0) (in crate0 truck1))
#
# (operator: (lift hoist6 crate6 crate2 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 146.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 76.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at truck0 distributor1) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at crate1 distributor2) (at pallet6 distributor2) (at truck1 depot0) (clear crate5) (clear crate2) (clear pallet0) (clear crate4) (clear pallet2) (clear pallet5) (clear pallet1) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate1 pallet6) (lifting hoist6 crate6) (in crate7 truck1) (in crate8 truck0) (in crate3 truck0) (in crate0 truck1))
#
# (operator: (drive truck0 distributor1 depot1))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 146.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 86.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate5 depot3) (at pallet6 distributor2) (at truck1 depot0) (at truck0 depot1) (clear pallet2) (clear pallet5) (clear crate4) (clear pallet1) (clear crate5) (clear pallet0) (clear crate2) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate1 pallet6) (on crate2 crate1) (on crate4 pallet4) (on crate5 pallet3) (lifting hoist6 crate6) (in crate7 truck1) (in crate8 truck0) (in crate3 truck0) (in crate0 truck1))
#
# (operator: (unload hoist0 crate7 truck1 depot0))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 88.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 86.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at crate1 distributor2) (at pallet6 distributor2) (at truck1 depot0) (at truck0 depot1) (clear pallet2) (clear pallet5) (clear pallet1) (clear crate2) (clear pallet0) (clear crate5) (clear crate4) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist3) (on crate1 pallet6) (on crate2 crate1) (on crate4 pallet4) (on crate5 pallet3) (lifting hoist6 crate6) (lifting hoist0 crate7) (in crate8 truck0) (in crate3 truck0) (in crate0 truck1))
#
# (operator: (drop hoist0 crate7 pallet0 depot0))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 88.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 86.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at pallet3 depot3) (at pallet0 depot0) (at crate7 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate5 depot3) (at pallet6 distributor2) (at truck1 depot0) (at truck0 depot1) (clear crate2) (clear crate5) (clear crate4) (clear pallet2) (clear pallet5) (clear crate7) (clear pallet1) (available hoist5) (available hoist4) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate1 pallet6) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate7 pallet0) (lifting hoist6 crate6) (in crate8 truck0) (in crate3 truck0) (in crate0 truck1))
#
# (operator: (drive truck1 depot0 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 88.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 96.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at hoist1 depot1) (at crate7 depot0) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at truck1 distributor2) (at crate5 depot3) (at pallet6 distributor2) (at truck0 depot1) (clear pallet2) (clear crate7) (clear pallet5) (clear crate4) (clear pallet1) (clear crate5) (clear crate2) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate1 pallet6) (on crate7 pallet0) (lifting hoist6 crate6) (in crate8 truck0) (in crate3 truck0) (in crate0 truck1))
#
# (operator: (load hoist6 crate6 truck1 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 147.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 96.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at crate7 depot0) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at truck1 distributor2) (at crate5 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at crate1 distributor2) (at pallet6 distributor2) (at truck0 depot1) (clear pallet2) (clear crate7) (clear pallet5) (clear pallet1) (clear crate2) (clear crate5) (clear crate4) (available hoist5) (available hoist4) (available hoist6) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate1 pallet6) (on crate7 pallet0)  (in crate8 truck0) (in crate3 truck0) (in crate0 truck1) (in crate6 truck1))
#
# (operator: (unload hoist6 crate0 truck1 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 59.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 96.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at crate7 depot0) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at truck1 distributor2) (at crate5 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at crate1 distributor2) (at pallet6 distributor2) (at truck0 depot1) (clear pallet2) (clear crate7) (clear pallet5) (clear crate4) (clear pallet1) (clear crate5) (clear crate2) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate1 pallet6) (on crate7 pallet0) (lifting hoist6 crate0) (in crate8 truck0) (in crate3 truck0) (in crate6 truck1))
#
# (operator: (drive truck0 depot1 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 59.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 106.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at crate7 depot0) (at pallet3 depot3) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at truck0 distributor2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at truck1 distributor2) (at crate5 depot3) (at pallet6 distributor2) (clear pallet2) (clear crate7) (clear pallet5) (clear pallet1) (clear crate2) (clear crate5) (clear crate4) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate1 pallet6) (on crate7 pallet0) (lifting hoist6 crate0) (in crate8 truck0) (in crate3 truck0) (in crate6 truck1))
#
# (operator: (drive truck1 distributor2 depot0))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 59.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 116.0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at crate7 depot0) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at truck0 distributor2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate5 depot3) (at pallet6 distributor2) (at truck1 depot0) (clear pallet2) (clear crate7) (clear pallet5) (clear crate4) (clear pallet1) (clear crate5) (clear crate2) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate1 pallet6) (on crate7 pallet0) (lifting hoist6 crate0) (in crate8 truck0) (in crate3 truck0) (in crate6 truck1))
#
# (operator: (unload hoist0 crate6 truck1 depot0))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 116.0) (at pallet2 depot2) (at pallet1 depot1) (at hoist1 depot1) (at crate7 depot0) (at pallet3 depot3) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate1 distributor2) (at pallet6 distributor2) (at truck1 depot0) (clear pallet2) (clear crate7) (clear pallet5) (clear pallet1) (clear crate2) (clear crate5) (clear crate4) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate1 pallet6) (on crate7 pallet0) (lifting hoist0 crate6) (lifting hoist6 crate0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (drop hoist0 crate6 crate7 depot0))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 116.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at crate7 depot0) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at truck0 distributor2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at crate5 depot3) (at pallet6 distributor2) (at truck1 depot0) (clear crate2) (clear crate6) (clear crate5) (clear crate4) (clear pallet2) (clear pallet5) (clear pallet1) (available hoist5) (available hoist4) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate6 crate7) (on crate1 pallet6) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate7 pallet0) (lifting hoist6 crate0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (drive truck1 depot0 depot1))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 126.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at crate7 depot0) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate2 distributor2) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at truck0 distributor2) (at pallet5 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at truck1 depot1) (at crate5 depot3) (at pallet6 distributor2) (clear pallet2) (clear pallet5) (clear crate4) (clear pallet1) (clear crate6) (clear crate5) (clear crate2) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate6 crate7) (on crate1 pallet6) (on crate7 pallet0) (lifting hoist6 crate0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (load hoist6 crate0 truck0 distributor2))
#
# (:state (= (current_load truck0) 195.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 126.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at crate7 depot0) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at pallet0 depot0) (at crate2 distributor2) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate1 distributor2) (at truck1 depot1) (at pallet6 distributor2) (clear pallet2) (clear pallet5) (clear pallet1) (clear crate2) (clear crate6) (clear crate5) (clear crate4) (available hoist5) (available hoist4) (available hoist6) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate2 crate1) (on crate6 crate7) (on crate1 pallet6) (on crate7 pallet0)  (in crate0 truck0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (lift hoist6 crate2 crate1 distributor2))
#
# (:state (= (current_load truck0) 195.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 127.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at crate7 depot0) (at pallet3 depot3) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at pallet0 depot0) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate1 distributor2) (at truck1 depot1) (at pallet6 distributor2) (clear crate1) (clear crate6) (clear crate5) (clear crate4) (clear pallet2) (clear pallet5) (clear pallet1) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate6 crate7) (on crate1 pallet6) (on crate7 pallet0) (lifting hoist6 crate2) (in crate0 truck0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (load hoist6 crate2 truck0 distributor2))
#
# ...
#
# (operator: (drive truck0 distributor1 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 147.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at crate7 depot0) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at truck0 distributor2) (at pallet5 distributor1) (at crate2 distributor1) (at hoist4 distributor0) (at crate1 distributor2) (at hoist0 depot0) (at truck1 depot1) (at crate5 depot3) (at pallet6 distributor2) (clear crate2) (clear pallet2) (clear pallet1) (clear crate1) (clear crate6) (clear crate5) (clear crate4) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate6 crate7) (on crate1 pallet6) (on crate2 pallet5) (on crate7 pallet0) (lifting hoist6 crate0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (load hoist6 crate0 truck0 distributor2))
#
# (:state (= (current_load truck0) 195.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 147.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at crate7 depot0) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at pallet0 depot0) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate2 distributor1) (at crate1 distributor2) (at truck1 depot1) (at pallet6 distributor2) (clear crate2) (clear pallet2) (clear crate1) (clear pallet1) (clear crate6) (clear crate5) (clear crate4) (available hoist5) (available hoist4) (available hoist6) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate6 crate7) (on crate1 pallet6) (on crate2 pallet5) (on crate7 pallet0)  (in crate0 truck0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (lift hoist6 crate1 pallet6 distributor2))
#
# (:state (= (current_load truck0) 195.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 148.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at crate7 depot0) (at pallet3 depot3) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at pallet0 depot0) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate2 distributor1) (at truck1 depot1) (at pallet6 distributor2) (clear crate2) (clear crate6) (clear pallet6) (clear crate5) (clear crate4) (clear pallet2) (clear pallet1) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate6 crate7) (on crate2 pallet5) (on crate7 pallet0) (lifting hoist6 crate1) (in crate0 truck0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (load hoist6 crate1 truck0 distributor2))
#
# (:state (= (current_load truck0) 280.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 148.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at crate7 depot0) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at pallet0 depot0) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate2 distributor1) (at truck1 depot1) (at pallet6 distributor2) (clear crate2) (clear pallet2) (clear pallet1) (clear crate6) (clear crate5) (clear crate4) (clear pallet6) (available hoist5) (available hoist4) (available hoist6) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate6 crate7) (on crate2 pallet5) (on crate7 pallet0)  (in crate0 truck0) (in crate8 truck0) (in crate3 truck0) (in crate1 truck0))
#
# (operator: (drive truck0 distributor2 depot1))
#
# (:state (= (current_load truck0) 280.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 158.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at crate7 depot0) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at crate2 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at truck1 depot1) (at crate5 depot3) (at pallet6 distributor2) (at truck0 depot1) (clear crate2) (clear pallet2) (clear pallet1) (clear crate6) (clear crate5) (clear crate4) (clear pallet6) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate6 crate7) (on crate2 pallet5) (on crate7 pallet0)  (in crate0 truck0) (in crate8 truck0) (in crate3 truck0) (in crate1 truck0))
#
# (operator: (unload hoist1 crate1 truck0 depot1))
#
# (:state (= (current_load truck0) 195.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 158.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at crate7 depot0) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at pallet0 depot0) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at crate2 distributor1) (at truck1 depot1) (at pallet6 distributor2) (at truck0 depot1) (clear crate2) (clear pallet2) (clear pallet1) (clear crate6) (clear crate5) (clear crate4) (clear pallet6) (available hoist5) (available hoist6) (available hoist2) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate6 crate7) (on crate2 pallet5) (on crate7 pallet0) (lifting hoist1 crate1) (in crate0 truck0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (drop hoist1 crate1 pallet1 depot1))
#
# (:state (= (current_load truck0) 195.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 158.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at crate7 depot0) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate4 distributor0) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at crate2 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at truck1 depot1) (at crate5 depot3) (at pallet6 distributor2) (at crate1 depot1) (at truck0 depot1) (clear crate2) (clear crate6) (clear pallet6) (clear crate5) (clear crate4) (clear pallet2) (clear crate1) (available hoist5) (available hoist6) (available hoist4) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate7 pallet0) (on crate1 pallet1) (on crate2 pallet5) (on crate6 crate7)  (in crate0 truck0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (unload hoist1 crate0 truck0 depot1))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 158.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at crate7 depot0) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at crate1 depot1) (at pallet0 depot0) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at crate2 distributor1) (at truck1 depot1) (at pallet6 distributor2) (at truck0 depot1) (clear crate2) (clear pallet2) (clear crate6) (clear crate5) (clear crate4) (clear pallet6) (clear crate1) (available hoist5) (available hoist6) (available hoist2) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate1 pallet1) (on crate6 crate7) (on crate2 pallet5) (on crate7 pallet0) (lifting hoist1 crate0) (in crate8 truck0) (in crate3 truck0))
#
# (operator: (drop hoist1 crate0 crate1 depot1))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 158.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at crate7 depot0) (at pallet3 depot3) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate4 distributor0) (at crate0 depot1) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at pallet5 distributor1) (at crate2 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at truck1 depot1) (at crate5 depot3) (at pallet6 distributor2) (at crate1 depot1) (at truck0 depot1) (clear crate0) (clear crate2) (clear crate6) (clear pallet6) (clear crate5) (clear crate4) (clear pallet2) (available hoist5) (available hoist6) (available hoist4) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate7 pallet0) (on crate1 pallet1) (on crate2 pallet5) (on crate0 crate1) (on crate6 crate7)  (in crate8 truck0) (in crate3 truck0))
#
# (operator: (drive truck0 depot1 distributor2))
#
# (:state (= (current_load truck0) 107.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 168.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at crate7 depot0) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate4 distributor0) (at crate0 depot1) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at truck0 distributor2) (at pallet5 distributor1) (at crate2 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at truck1 depot1) (at crate5 depot3) (at pallet6 distributor2) (at crate1 depot1) (clear crate2) (clear pallet2) (clear crate0) (clear crate6) (clear crate5) (clear crate4) (clear pallet6) (available hoist5) (available hoist6) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate1 pallet1) (on crate6 crate7) (on crate0 crate1) (on crate2 pallet5) (on crate7 pallet0)  (in crate8 truck0) (in crate3 truck0))
#
# (operator: (unload hoist6 crate8 truck0 distributor2))
#
# (:state (= (current_load truck0) 40.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 168.0) (at crate6 depot0) (at pallet2 depot2) (at pallet1 depot1) (at crate7 depot0) (at pallet3 depot3) (at hoist1 depot1) (at hoist5 distributor1) (at crate4 distributor0) (at crate0 depot1) (at pallet4 distributor0) (at pallet5 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at crate5 depot3) (at crate1 depot1) (at pallet0 depot0) (at hoist6 distributor2) (at hoist3 depot3) (at hoist2 depot2) (at truck0 distributor2) (at crate2 distributor1) (at truck1 depot1) (at pallet6 distributor2) (clear crate2) (clear pallet2) (clear crate0) (clear crate6) (clear crate5) (clear crate4) (clear pallet6) (available hoist5) (available hoist2) (available hoist1) (available hoist4) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate5 pallet3) (on crate1 pallet1) (on crate6 crate7) (on crate0 crate1) (on crate2 pallet5) (on crate7 pallet0) (lifting hoist6 crate8) (in crate3 truck0))
#
# (operator: (drop hoist6 crate8 pallet6 distributor2))
#
# (:state (= (current_load truck0) 40.0) (= (load_limit truck0) 454.0) (= (current_load truck1) 0.0) (= (load_limit truck1) 265.0) (= (weight crate0) 88.0) (= (weight crate1) 85.0) (= (weight crate2) 93.0) (= (weight crate3) 40.0) (= (weight crate4) 28.0) (= (weight crate5) 85.0) (= (weight crate6) 59.0) (= (weight crate7) 58.0) (= (weight crate8) 67.0) (= (fuel-cost ) 168.0) (at crate6 depot0) (at crate8 distributor2) (at pallet2 depot2) (at pallet1 depot1) (at pallet3 depot3) (at crate7 depot0) (at hoist1 depot1) (at pallet0 depot0) (at hoist5 distributor1) (at crate4 distributor0) (at crate0 depot1) (at hoist6 distributor2) (at hoist3 depot3) (at pallet4 distributor0) (at hoist2 depot2) (at truck0 distributor2) (at pallet5 distributor1) (at crate2 distributor1) (at hoist4 distributor0) (at hoist0 depot0) (at truck1 depot1) (at crate5 depot3) (at pallet6 distributor2) (at crate1 depot1) (clear crate0) (clear crate2) (clear crate6) (clear crate8) (clear crate5) (clear crate4) (clear pallet2) (available hoist5) (available hoist4) (available hoist6) (available hoist2) (available hoist1) (available hoist0) (available hoist3) (on crate4 pallet4) (on crate8 pallet6) (on crate5 pallet3) (on crate7 pallet0) (on crate1 pallet1) (on crate2 pallet5) (on crate0 crate1) (on crate6 crate7)  (in crate3 truck0))
#
# )

# %%
Path(DEPOTS_TRAJECTORY_PATH).unlink(missing_ok=True)
